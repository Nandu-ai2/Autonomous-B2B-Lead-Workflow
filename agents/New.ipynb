# %%
import os, sys
os.chdir(r"C:\Users\kesir\OneDrive\Desktop\PRRR")
sys.path.append(os.getcwd())

from langgraph_builder import LangGraphExecutor

executor = LangGraphExecutor()
executor.run()


import json
with open("run_context.json", "w") as f:
    json.dump(executor.context, f, indent=2)

print("✅ Workflow completed. Saved as run_context.json")
# Out:
# ✅ Loaded workflow: OutboundLeadGenerationV2
#
# 🧩 Starting LangGraph Workflow Execution
#
# 🚀 Running Step [prospect_search] — Agent: ProspectSearchAgent
# [LOG] ProspectSearch: ICP= {'industry': 'SaaS', 'location': 'USA', 'employee_count': {'min': 100, 'max': 1000}, 'revenue': {'min': 20000000, 'max': 200000000}} signals= ['recent_funding', 'hiring_for_sales']
# ✅ Step prospect_search completed. Output keys: ['leads']
#
# 🚀 Running Step [enrichment] — Agent: DataEnrichmentAgent
# [LOG] Enriching 4 leads
# ✅ Step enrichment completed. Output keys: ['enriched_leads']
#
# 🚀 Running Step [scoring] — Agent: ScoringAgent
# [LOG] Scoring with criteria {'weights': {'revenue': 0.3, 'employee_count': 0.2, 'signal_match': 0.4, 'tech_stack': 0.1}}
# ✅ Step scoring completed. Output keys: ['ranked_leads']
#
# 🚀 Running Step [outreach_content] — Agent: OutreachContentAgent
# [LOG] Generating content persona= SDR tone= friendly
# ✅ Step outreach_content completed. Output keys: ['messages']
#
# ...
